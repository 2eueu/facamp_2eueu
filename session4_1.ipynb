# %% [markdown]
# ## Game Replay using Tracking Data

# %%
from kloppy import metrica 
import matplotlib.pyplot as plt 
from mplsoccer import Pitch 
import os 
from tqdm import tqdm

# %% [markdown]
# ## Load Tracking Data

# %%
dataset=metrica.load_open_data(match_id=1)

# %%
len(dataset.records)
# Out:
# 145006

# %%
dataset.records[0].timestamp
# Out:
# 0.0

# %%
dataset.records[-1].timestamp
# Out:
# 2949.4799999999996

# %% [markdown]
# ## Metadata

# %%
metadata=dataset.metadata

# %% [markdown]
# ## Home Team and Away Team

# %%
team_home, team_away=metadata.teams

# %% [markdown]
# ## Players

# %%
for player in team_home.players:
    print(player.player_id)
# Out:
# home_11
# home_1
# home_2
# home_3
# home_4
# home_5
# home_6
# home_7
# home_8
# home_9
# home_10
# home_12
# home_13
# home_14

# %% [markdown]
# ## Frames

# %%
len(dataset.frames)
# Out:
# 145006

# %%
# first ten frames
dataset.frames[:10]
# Out:
# [<Frame>,
#  <Frame>,
#  <Frame>,
#  <Frame>,
#  <Frame>,
#  <Frame>,
#  <Frame>,
#  <Frame>,
#  <Frame>,
#  <Frame>]

# %% [markdown]
# ## Ball Coordinates

# %%
for frame in dataset.frames[:10]:
    print(frame.ball_coordinates)
# Out:
# Point(x=0.45472, y=0.6129100000000001)
# Point(x=0.49645, y=0.59344)
# Point(x=0.53716, y=0.5744400000000001)
# Point(x=0.55346, y=0.57769)
# Point(x=0.55512, y=0.5943)
# Point(x=0.55677, y=0.6109100000000001)
# Point(x=0.55842, y=0.6275200000000001)
# Point(x=0.56004, y=0.64371)
# Point(x=0.56173, y=0.66074)
# Point(x=0.56338, y=0.67735)

# %% [markdown]
# ## Player Coordinates

# %%
for frame in dataset.frames[:10]:
    for player, coord in frame.players_coordinates.items():
        if player.team.name=="Home":
            print(player.player_id, coord)
# Out:
# home_11 Point(x=0.00082, y=0.51762)
# home_1 Point(x=0.32648, y=0.34678)
# home_2 Point(x=0.33701, y=0.51137)
# home_3 Point(x=0.30927, y=0.64471)
# home_4 Point(x=0.32137, y=0.78738)
# home_5 Point(x=0.41094, y=0.27410999999999996)
# home_6 Point(x=0.41698, y=0.52157)
# home_7 Point(x=0.39125, y=0.6745)
# home_8 Point(x=0.45388, y=0.78826)
# home_9 Point(x=0.52697, y=0.6202)
# home_10 Point(x=0.55243, y=0.56731)
# home_11 Point(x=0.00096, y=0.51762)
# home_1 Point(x=0.32648, y=0.34678)
# home_2 Point(x=0.33701, y=0.51137)
# home_3 Point(x=0.30927, y=0.64471)
# home_4 Point(x=0.32137, y=0.78738)
# home_5 Point(x=0.41094, y=0.27410999999999996)
# home_6 Point(x=0.41698, y=0.52157)
# home_7 Point(x=0.39125, y=0.6745)
# home_8 Point(x=0.45388, y=0.78826)
# home_9 Point(x=0.52697, y=0.6202)
# home_10 Point(x=0.55243, y=0.56731)
# home_11 Point(x=0.00114, y=0.51762)
# home_1 Point(x=0.32648, y=0.34678)
# home_2 Point(x=0.33701, y=0.51137)
# home_3 Point(x=0.30927, y=0.64471)
# home_4 Point(x=0.32137, y=0.78738)
# home_5 Point(x=0.41094, y=0.27410999999999996)
# home_6 Point(x=0.41698, y=0.52157)
# home_7 Point(x=0.39125, y=0.6745)
# home_8 Point(x=0.45388, y=0.78826)
# home_9 Point(x=0.52697, y=0.6202)
# home_10 Point(x=0.55243, y=0.56731)
# home_11 Point(x=0.00121, y=0.51762)
# home_1 Point(x=0.32622, y=0.34682999999999997)
# home_2 Point(x=0.33687, y=0.51012)
# home_3 Point(x=0.30944, y=0.64446)
# home_4 Point(x=0.32142, y=0.78759)
# home_5 Point(x=0.41067, y=0.27435)
# home_6 Point(x=0.41703, y=0.52035)
# home_7 Point(x=0.39134, y=0.6743399999999999)
# home_8 Point(x=0.45379, y=0.78947)
# home_9 Point(x=0.52731, y=0.6199)
# home_10 Point(x=0.55236, y=0.56687)
# home_11 Point(x=0.00129, y=0.51762)
# home_1 Point(x=0.32597, y=0.34731)
# home_2 Point(x=0.33664, y=0.5098199999999999)
# home_3 Point(x=0.30948, y=0.64472)
# home_4 Point(x=0.32136, y=0.78841)
# home_5 Point(x=0.41065, y=0.27490000000000003)
# home_6 Point(x=0.41682, y=0.52048)
# home_7 Point(x=0.39141, y=0.6757299999999999)
# home_8 Point(x=0.45376, y=0.7905)
# home_9 Point(x=0.52737, y=0.62009)
# home_10 Point(x=0.55202, y=0.56689)
# home_11 Point(x=0.0014, y=0.51762)
# home_1 Point(x=0.32581, y=0.34841)
# home_2 Point(x=0.33637, y=0.51034)
# home_3 Point(x=0.30978, y=0.6452100000000001)
# home_4 Point(x=0.32159, y=0.78949)
# home_5 Point(x=0.41082, y=0.27561)
# home_6 Point(x=0.41663, y=0.5218)
# home_7 Point(x=0.3919, y=0.6767799999999999)
# home_8 Point(x=0.4538, y=0.7921199999999999)
# home_9 Point(x=0.5274, y=0.62151)
# home_10 Point(x=0.55256, y=0.5720700000000001)
# home_11 Point(x=0.0014, y=0.51762)
# home_1 Point(x=0.3257, y=0.34963)
# home_2 Point(x=0.33624, y=0.51081)
# home_3 Point(x=0.31015, y=0.64561)
# home_4 Point(x=0.32198, y=0.79079)
# home_5 Point(x=0.41094, y=0.27703)
# home_6 Point(x=0.41641, y=0.52318)
# home_7 Point(x=0.39235, y=0.6784)
# home_8 Point(x=0.45378, y=0.79406)
# home_9 Point(x=0.52746, y=0.62347)
# home_10 Point(x=0.55307, y=0.57454)
# home_11 Point(x=0.0014, y=0.51762)
# home_1 Point(x=0.32564, y=0.35084000000000004)
# home_2 Point(x=0.33608, y=0.5113099999999999)
# home_3 Point(x=0.3105, y=0.64627)
# home_4 Point(x=0.32243, y=0.79227)
# home_5 Point(x=0.411, y=0.27849)
# home_6 Point(x=0.41618, y=0.52467)
# home_7 Point(x=0.39281, y=0.68014)
# home_8 Point(x=0.45375, y=0.7957)
# home_9 Point(x=0.52752, y=0.62554)
# home_10 Point(x=0.55333, y=0.57685)
# home_11 Point(x=0.0012, y=0.51807)
# home_1 Point(x=0.32557, y=0.35222)
# home_2 Point(x=0.33593, y=0.5119)
# home_3 Point(x=0.31089, y=0.6467499999999999)
# home_4 Point(x=0.32282, y=0.79394)
# home_5 Point(x=0.41109, y=0.28002000000000005)
# home_6 Point(x=0.41592, y=0.52596)
# home_7 Point(x=0.39319, y=0.68182)
# home_8 Point(x=0.45374, y=0.79748)
# home_9 Point(x=0.52754, y=0.62775)
# home_10 Point(x=0.55349, y=0.5791299999999999)
# home_11 Point(x=0.001, y=0.5185299999999999)
# home_1 Point(x=0.32551, y=0.35363)
# home_2 Point(x=0.33581, y=0.51244)
# home_3 Point(x=0.31133, y=0.64735)
# home_4 Point(x=0.32312, y=0.79555)
# home_5 Point(x=0.41119, y=0.28163000000000005)
# home_6 Point(x=0.41563, y=0.5276000000000001)
# home_7 Point(x=0.39362, y=0.68333)
# home_8 Point(x=0.45371, y=0.7992)
# home_9 Point(x=0.52761, y=0.63042)
# home_10 Point(x=0.55346, y=0.5812999999999999)

# %% [markdown]
# ## Pitch

# %%
pitch = Pitch( 
    pitch_color="grass", 
    line_color="white", 
    stripe= True
)

fig, ax= pitch.draw()

plt.show()

# %% [markdown]
# ## First Frame

# %%
pitch= Pitch(
    pitch_type="metricasports", 
    pitch_width=68, pitch_length=105, 
    pitch_color="grass", 
    line_color="white", 
    stripe= True
) 

fig, ax= pitch.draw()

# the very first frame 
frame= dataset.frames[0] 

for player, coord in frame.players_coordinates.items():
    if player.team.name=="Home":
        pitch.plot(coord.x, coord.y, marker="s", color="yellow", markeredgecolor="black", zorder=1, ax=ax)
    else:
        pitch.plot(coord.x, coord.y, marker="s", color="red", markeredgecolor="black", zorder=1, ax=ax)

plt.show()

# %% [markdown]
# ## First 50 Frames

# %% [markdown]
# ### Players

# %%
pitch= Pitch( 
    pitch_type="metricasports", 
    pitch_width=68, pitch_length=105, 
    pitch_color="grass", 
    line_color="white",
    stripe= True
)

fig, ax= pitch.draw()

for frame in dataset.frames[:50]: 
    for player, coord in frame.players_coordinates.items(): 
        if player.team.name=="Home": 
            pitch.plot(coord.x, coord.y, marker="s", color="yellow", markeredgecolor="black", zorder=1, ax=ax)
        else: 
            pitch.plot(coord.x, coord.y, marker="s", color="red", markeredgecolor="black", zorder=1, ax=ax)


plt.show()

# %% [markdown]
# ## Players and the Ball

# %%
pitch= Pitch(
    pitch_type="metricasports",
    pitch_width=68, pitch_length=105,
    pitch_color="grass", 
    line_color="white", 
    stripe= True
)

fig, ax= pitch.draw()

for frame in dataset.frames[:50]:

    pitch.scatter(
        frame.ball_coordinates.x, 
        frame.ball_coordinates.y, 
        marker="football", s=100, 
        zorder=999, 
        ax=ax
    )

    for player, coord in frame.players_coordinates.items(): 
        if player.team.name=="Home":
            pitch.plot(coord.x, coord.y, marker="s", color="yellow", markeredgecolor="black", zorder=1, ax=ax) 
        else: 
            pitch.plot(coord.x, coord.y, marker="s", color="red", markeredgecolor="black", zorder=1, ax=ax)

plt.show()

# %% [markdown]
# ## Convert to DataFrame

# %%
df= dataset.to_df(engine="pandas")

# %%
df
# Out:
#         period_id  timestamp  frame_id ball_state ball_owning_team_id  \
# 0               1       0.00         1       None                None
# 1               1       0.04         2       None                None
# 2               1       0.08         3       None                None
# 3               1       0.12         4       None                None
# 4               1       0.16         5       None                None
# ...           ...        ...       ...        ...                 ...
# 145001          2    2949.32    145002       None                None
# 145002          2    2949.36    145003       None                None
# 145003          2    2949.40    145004       None                None
# 145004          2    2949.44    145005       None                None
# 145005          2    2949.48    145006       None                None
#
#          ball_x   ball_y ball_z ball_speed  home_11_x  ...  home_13_d  \
# 0       0.45472  0.61291   None       None    0.00082  ...       None
# 1       0.49645  0.59344   None       None    0.00096  ...       None
# 2       0.53716  0.57444   None       None    0.00114  ...       None
# 3       0.55346  0.57769   None       None    0.00121  ...       None
# 4       0.55512  0.59430   None       None    0.00129  ...       None
# ...         ...      ...    ...        ...        ...  ...        ...
# 145001      NaN      NaN   None       None    0.90614  ...       None
# 145002      NaN      NaN   None       None    0.90550  ...       None
# 145003      NaN      NaN   None       None    0.90492  ...       None
# 145004      NaN      NaN   None       None    0.90456  ...       None
# 145005      NaN      NaN   None       None    0.90456  ...       None
#
#        home_13_s away_28_x  away_28_y  away_28_d away_28_s home_14_x  \
# 0           None       NaN        NaN       None      None       NaN
# 1           None       NaN        NaN       None      None       NaN
# 2           None       NaN        NaN       None      None       NaN
# 3           None       NaN        NaN       None      None       NaN
# 4           None       NaN        NaN       None      None       NaN
# ...          ...       ...        ...        ...       ...       ...
# 145001      None   0.21798    0.18921       None      None   0.34157
# 145002      None   0.21798    0.18921       None      None   0.34127
# 145003      None   0.21798    0.18921       None      None   0.34089
# 145004      None   0.21798    0.18921       None      None   0.34056
# 145005      None   0.21798    0.18921       None      None   0.33996
#
#         home_14_y  home_14_d home_14_s
# 0             NaN       None      None
# 1             NaN       None      None
# 2             NaN       None      None
# 3             NaN       None      None
# 4             NaN       None      None
# ...           ...        ...       ...
# 145001    0.35402       None      None
# 145002    0.35417       None      None
# 145003    0.35431       None      None
# 145004    0.35448       None      None
# 145005    0.35456       None      None
#
# [145006 rows x 121 columns]

# %% [markdown]
# ## Animation

# %% [markdown]
# ### FFmpeg

# %% [markdown]
# conda activate facamp
# conda install conda-forge::ffmpeg

# %% [markdown]
# ### First 100 Frames

# %% [markdown]
# Create Frame Images

# %%
path_base="anim1a"

# %%
os.makedirs(path_base, exist_ok=True)

# %%
pitch= Pitch(
    pitch_type="metricasports", 
    pitch_width=68, pitch_length=105, 
    pitch_color="grass",
    line_color="white", 
    stripe=True
)

n=0
max_frames=100 

for frame in tqdm(dataset.frames[:max_frames]):

    n +=1

    fig, ax= pitch.draw()

    pitch.scatter(
        frame.ball_coordinates.x, 
        frame.ball_coordinates.y,
        marker="football", s= 100, 
        zorder=999,
        ax=ax
    )

    for player, coord in frame.players_coordinates.items():
        if player.team.name=="Home": 
            pitch.plot(coord.x, coord.y, marker="s", color="yellow", markeredgecolor="black", zorder=1, ax=ax)
        else: 
            pitch.plot(coord.x, coord.y, marker="s", color="red", markeredgecolor="black", zorder=1, ax=ax)

    path_dst=os.path.join(path_base, f"{n:03d}.png")
    plt.savefig(path_dst)

    # clean up
    fig.clear()
    plt.close(fig)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:53<00:00,  1.73s/it]

# %% [markdown]
# ## Convert Images to Video

# %% [markdown]
# ### Windows

# %%
# !ffmpeg -framerate 30 -i anim1a/%03d.png -c:v libx264 -pix_fmt yuv420p anim1a.mp4
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with clang version 18.1.6
#   configuration: --prefix=/d/bld/ffmpeg_1716729588356/_h_env/Library --cc=clang.exe --cxx=clang++.exe --nm=llvm-nm --ar=llvm-ar --disable-doc --disable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --ld=lld-link --target-os=win64 --enable-cross-compile --toolchain=msvc --host-cc=clang.exe --extra-libs=ucrt.lib --extra-libs=vcruntime.lib --extra-libs=oldnames.lib --strip=llvm-strip --disable-stripping --host-extralibs= --disable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --pkg-config=/d/bld/ffmpeg_1716729588356/_build_env/Library/bin/pkg-config
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, image2, from 'anim1a/%03d.png':
#   Duration: 00:00:03.33, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 640x480 [SAR 3937:3937 DAR 4:3], 30 fps, 30 tbr, 30 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0000020C6ED932C0] using SAR=1/1
# [libx264 @ 0000020C6ED932C0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0000020C6ED932C0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0000020C6ED932C0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'anim1a.mp4':
#   Metadata:
#     encoder         : Lavf61.1.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], q=2-31, 30 fps, 15360 tbn
#       Metadata:
#         encoder         : Lavc61.3.100 libx264
#       Side data:
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   22 fps=0.0 q=29.0 size=       0KiB time=00:00:00.66 bitrate=   0.6kbits/s speed=1.31x
# [out#0/mp4 @ 0000020C6D09AC80] video:94KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 2.138512%
# frame=  100 fps=0.0 q=-1.0 Lsize=      96KiB time=00:00:03.26 bitrate= 241.8kbits/s speed=4.32x
# [libx264 @ 0000020C6ED932C0] frame I:1     Avg QP:24.26  size:  7689
# [libx264 @ 0000020C6ED932C0] frame P:25    Avg QP:24.44  size:  1438
# [libx264 @ 0000020C6ED932C0] frame B:74    Avg QP:25.82  size:   707
# [libx264 @ 0000020C6ED932C0] consecutive B-frames:  1.0%  0.0%  3.0% 96.0%
# [libx264 @ 0000020C6ED932C0] mb I  I16..4: 70.3% 10.3% 19.3%
# [libx264 @ 0000020C6ED932C0] mb P  I16..4:  0.9%  1.7%  0.1%  P16..4: 15.7%  2.6%  2.1%  0.0%  0.0%    skip:76.8%
# [libx264 @ 0000020C6ED932C0] mb B  I16..4:  1.4%  0.3%  0.0%  B16..8: 25.8%  0.6%  0.1%  direct: 0.7%  skip:71.1%  L0:57.1% L1:41.7% BI: 1.2%
# [libx264 @ 0000020C6ED932C0] 8x8 transform intra:25.6% inter:89.3%
# [libx264 @ 0000020C6ED932C0] coded y,uvDC,uvAC intra: 23.1% 24.8% 6.6% inter: 5.4% 3.5% 0.8%
# [libx264 @ 0000020C6ED932C0] i16 v,h,dc,p: 74% 17%  5%  3%
# [libx264 @ 0000020C6ED932C0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 10% 50%  8%  4%  4%  4%  3%  3%
# [libx264 @ 0000020C6ED932C0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 43% 19% 22%  3%  3%  3%  2%  3%  2%
# [libx264 @ 0000020C6ED932C0] i8c dc,h,v,p: 38% 13% 47%  1%
# [libx264 @ 0000020C6ED932C0] Weighted P-Frames: Y:68.0% UV:48.0%
# [libx264 @ 0000020C6ED932C0] ref P L0: 50.6%  6.1% 27.2% 10.5%  5.4%
# [libx264 @ 0000020C6ED932C0] ref B L0: 55.5% 36.2%  8.3%
# [libx264 @ 0000020C6ED932C0] ref B L1: 83.7% 16.3%
# [libx264 @ 0000020C6ED932C0] kb/s:230.32

# %% [markdown]
# ### First 3,500 Frames

# %% [markdown]
# ### Create Frames Images

# %%
path_base="anim1b"

# %%
os.makedirs(path_base, exist_ok=True)

# %%
pitch= Pitch(
    pitch_type="metricasports", 
    pitch_width=68, pitch_length=105, 
    pitch_color="grass", 
    line_color="white", 
    stripe=True
)

n=0
max_frames=3500

for frame in tqdm(dataset.frames[:max_frames]):

    n+=1

    fig, ax= pitch.draw()

    if frame.ball_coordinates is not None: 
        pitch.scatter(
            frame.ball_coordinates.x, 
            frame.ball_coordinates.y,
            marker="football", s= 100, 
            zorder=999,
            ax=ax
        )

    for player, coord in frame.players_coordinates.items(): 
        if player.team.name=="Home":
            pitch.plot(coord.x, coord.y, marker="s", color="yellow", markeredgecolor="black", zorder=1, ax=ax)
        else: 
            pitch.plot(coord.x, coord.y, marker="s", color="red", markeredgecolor="black", zorder=1, ax=ax)

    path_dst=os.path.join(path_base, f"{n:06d}.png")
    plt.savefig(path_dst)

    # clean up 
    fig.clear()
    plt.close(fig)
# Out:
#   0%|                                                                               | 2/3500 [00:03<1:31:36,  1.57s/it]

# %% [markdown]
# ## Convert Images to Video

# %% [markdown]
# ### Windows

# %% [markdown]
# ffmpeg -framerate 30 -i anim1b/%06d.png -c:v libx264 -pix_fmt yuv420p anim1b.mp4
